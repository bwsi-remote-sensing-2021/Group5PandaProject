# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 100 
pd.options.display.max_columns = 50

url = "https://www.fema.gov/api/open/v2/DisasterDeclarationsSummaries.csv"
disasterDataDf = pd.read_csv(url, index_col='state')

# %%
disasterDataDf = disasterDataDf.drop(['id','lastRefresh','hash','declarationRequestNumber','placeCode','fipsCountyCode','fipsStateCode','hmProgramDeclared','paProgramDeclared','iaProgramDeclared','ihProgramDeclared','fyDeclared','declarationTitle','disasterNumber','femaDeclarationString','disasterNumber','declarationType','incidentBeginDate','incidentEndDate'],axis = 1)
disasterDataDf.head(20)
# Out:
#                 declarationDate incidentType      disasterCloseoutDate  \
# state
# MA     1953-06-11T00:00:00.000Z      Tornado  1956-06-01T00:00:00.000Z
# TX     1953-06-19T00:00:00.000Z        Flood  1958-01-01T00:00:00.000Z
# IA     1953-06-11T00:00:00.000Z        Flood  1955-11-01T00:00:00.000Z
# NH     1953-07-02T00:00:00.000Z         Fire  1956-02-01T00:00:00.000Z
# MI     1953-06-09T00:00:00.000Z      Tornado  1956-03-30T00:00:00.000Z
# MT     1953-06-06T00:00:00.000Z        Flood  1955-12-01T00:00:00.000Z
# LA     1953-05-29T00:00:00.000Z        Flood  1960-02-01T00:00:00.000Z
# MI     1953-06-02T00:00:00.000Z      Tornado  1956-02-01T00:00:00.000Z
# GA     1953-05-02T00:00:00.000Z      Tornado  1954-06-01T00:00:00.000Z
# TX     1953-05-15T00:00:00.000Z      Tornado  1958-01-01T00:00:00.000Z
# TX     1954-07-01T00:00:00.000Z        Flood  1959-07-01T00:00:00.000Z
# MS     1953-12-06T00:00:00.000Z      Tornado  1956-06-01T00:00:00.000Z
# ...

# %%
p = disasterDataDf.groupby('incidentType').apply(lambda col: [np.min(col), np.max(col)])
p
# Out:
# incidentType
# Biological                                                   [[], []]
# Chemical            [[2014-01-10T00:30:00.000Z, Chemical, 2016-06-...
# Coastal Storm                                                [[], []]
# Dam/Levee Break                                              [[], []]
# Drought             [[1963-11-27T00:00:00.000Z, Drought, 1964-06-1...
# Earthquake                                                   [[], []]
# Fire                                                         [[], []]
# Fishing Losses      [[1972-09-28T00:00:00.000Z, Fishing Losses, 19...
# Flood                                                        [[], []]
# Freezing                                                     [[], []]
# Human Cause         [[1980-05-06T00:00:00.000Z, Human Cause, 1994-...
# Hurricane                                                    [[], []]
# Mud/Landslide                                                [[], []]
# ...
